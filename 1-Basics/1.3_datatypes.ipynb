# %% [markdown]
# DATATYPES

# %%
# Datatypes in python are the classification or categorization of data items. 
# It represents the kind of value that tells what operations can be performed on a particular data. 
# Python is a dynamically typed language, which means that you don’t need to declare the type of variable while declaring it. 
# The interpreter infers the type of variable based on the value assigned to it.
# Basic data types in Python include:
# 1. Numeric Types: int, float, complex
# 2. Text Type: str
# 3. Boolean Type: bool
# 4. Sequence Types: list, tuple, range
# 5. Mapping Type: dict
# 6. Set Types: set, frozenset
# 7. Binary Types: bytes, bytearray, memoryview 
a= 10  # int 
b= 10.5  # float
c  = 3 + 4j  # complex
d = "Hello, World!"  # str
e = True  # bool
f = [1, 2, 3, 4, 5]  # list
g = (1, 2, 3, 4, 5)  # tuple
h = {1, 2, 3, 4, 5}  # set
i = {'name': 'Alice', 'age': 25}  # dict
j = range(5)  # range
k = b'Hello'  # bytes
l = bytearray(b'Hello')  # bytearray
m = memoryview(b'Hello')  # memoryview

# %%
print(type(bool(0)))  # Output: <class 'bool'>
print(type(bool(1)))  # Output: <class 'bool'>
print(type(bool("")))  # Output: <class 'bool'>
print(type(bool("Hello")))  # Output: <class 'bool'>    
print(type(bool([])))  # Output: <class 'bool'>
print(bool())  # Output: False
print(bool(0))  # Output: False
print(bool(1))  # Output: True
print(bool("Hello"))  # Output: True
print(bool([]))  # Output: False
print(bool([1, 2, 3]))  # Output: True
print(bool(None))  # Output: False
print(bool(False))  # Output: False
print(bool(True))  # Output: True
print(bool(0.0))  # Output: False
print(bool(0.1))  # Output: True
print(bool({}))  # Output: False
print(bool({'key': 'value'}))  # Output: True
print(bool(set()))  # Output: False
# Out:
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# False
# False
# True
# True
# False
# True
# False
# False
# True
# False
# True
# False
# True
# False

# %%
a=10
b=10
type(a==b)  # Output: <class 'bool'>
# Out:
# bool

# %%
# Common Errors:
# 1. TypeError: This error occurs when an operation or function is applied to  an object of inappropriate type. For example, trying to add a string and an integer will raise a TypeError.
# 2. ValueError: This error occurs when a function receives an argument of correct type but inappropriate value. For example, trying to convert a string to an integer when the string is not a valid integer will raise a ValueError.
# 3. NameError: This error occurs when a variable or function name is not found in the current scope. For example, trying to use a variable that has not been defined will raise a NameError.  
# example:
# TypeError
a = "Hello"         
b = 5
c = a + b # Output: TypeError: can only concatenate str (not "int") to str

# ValueError
a = "Hello"
b = int(a) # Output: ValueError: invalid literal for int() with base 10: 'Hello' 

# NameError
print(x) # Output: NameError: name 'x' is not defined
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 9
#       7 a = "Hello"
#       8 b = 5
# ----> 9 c = a + b
#
# TypeError: can only concatenate str (not "int") to str
